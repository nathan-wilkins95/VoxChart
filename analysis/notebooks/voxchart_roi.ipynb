# %% [markdown]
# # VoxChart ROI Analysis
# **Vox Medical** — Less charting. More caring.
#
# This notebook walks through the full cost-efficiency analysis for VoxChart.

# %%
import sys
sys.path.insert(0, '../scripts')
from analysis import *
from charts import *
import pandas as pd
df = build_roi_table()
df.head(10)

# %% [markdown]
# ## 1. Net Annual ROI by Unit Size

# %%
chart_net_roi()

# %% [markdown]
# ## 2. Monthly Savings vs VoxChart Cost

# %%
chart_savings_vs_cost()

# %% [markdown]
# ## 3. Breakeven Analysis

# %%
chart_breakeven()
build_breakeven_table()

# %% [markdown]
# ## 4. Nurse Retention Savings

# %%
chart_retention()
build_retention_table()

# %% [markdown]
# ## 5. 5-Year Cumulative ROI

# %%
chart_5yr()
build_5yr_projection()

# %% [markdown]
# ## 6. Custom Scenario
# Edit the values below to model your specific hospital unit.

# %%
custom_nurses = 30
custom_scenario = 'Moderate (25 min)'
df_custom = build_5yr_projection(nurses=custom_nurses, scenario=custom_scenario)
df_custom
